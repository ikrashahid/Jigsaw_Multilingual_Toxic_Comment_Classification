# %% [markdown]
# # Part 4 - Mitigation
#
# Run and compare mitigation techniques against baseline fairness and utility.

# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
from fairlearn.postprocessing import ThresholdOptimizer
from sklearn.metrics import f1_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from assignment_workflow import load_and_split_data, tokenize_df, cohort_metrics

train_df, eval_df = load_and_split_data('jigsaw-unintended-bias-train.csv')
model_dir = 'saved_model/part1_baseline'
tokenizer = AutoTokenizer.from_pretrained(model_dir)
model = AutoModelForSequenceClassification.from_pretrained(model_dir)
trainer = Trainer(model=model, args=TrainingArguments(output_dir='tmp_part4', report_to=[]))
eval_dataset = tokenize_df(eval_df, tokenizer)
base_prob = torch.softmax(torch.tensor(trainer.predict(eval_dataset).predictions), dim=1).numpy()[:,1]

# %%
# Technique 2 placeholder (post-processing with Fairlearn)
groups = np.where(eval_df['black'] >= 0.5, 'high_black', 'reference_or_other')
th = ThresholdOptimizer(estimator=None, constraints='equalized_odds', predict_method='predict_proba')
print('Implement full mitigation loops for all three techniques here and fill final comparison table.')
